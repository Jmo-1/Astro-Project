# %%
import numpy as np
import matplotlib as plt
import pandas as pd

# %%
#Setting up plot

fontsize = 20
figsize = (10,7)

# Configure parameters
plt.rcParams.update({'font.size': fontsize, 'figure.figsize': figsize})

# Set default tick and axes properties
plt.rcParams['xtick.labelsize'] = fontsize
plt.rcParams['ytick.labelsize'] = fontsize
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.rcParams['xtick.major.size'] = 8
plt.rcParams['ytick.major.size'] = 8
plt.rcParams['xtick.major.width'] = 4
plt.rcParams['ytick.major.width'] = 4
plt.rcParams['xtick.minor.size'] = 6
plt.rcParams['ytick.minor.size'] = 6
plt.rcParams['xtick.minor.width'] = 2
plt.rcParams['ytick.minor.width'] = 2
plt.rcParams['xtick.top'] = True
plt.rcParams['ytick.right'] = True
plt.rcParams['axes.linewidth'] = 3

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('Cmp v Att Offense.csv')

#Championship team
z = 2019
champ_cmp = 24.1
champ_att = 37.5

#Making graph wider
plt.figure(figsize=(10, 5))

#Plotting offensive data
plt.plot(df['Year'], df['Cmp'], marker='o', label='Completions')
plt.plot(df['Year'], df['Att_pass'], marker='o', label='Attempts')

#Plot championship team points
plt.plot([z], [champ_cmp], marker='o', color='maroon')
plt.plot([z], [champ_att], marker='o', color='maroon')

plt.axhline(y=champ_cmp, color='maroon', linestyle='--', linewidth=1)
plt.axhline(y=champ_att, color='maroon', linestyle='--', linewidth=1)

plt.title('Passing Trends 2020–2024 (Offense)')
plt.xlabel('Year')
plt.ylabel('Per Game Average')
plt.ylim(0, 40)
plt.grid(True)
plt.tick_params(top=False)
plt.legend(fontsize=10)

#Custom x-axis labels and ticks
custom_ticks = list(df['Year']) + [z]
custom_ticks = sorted(set(custom_ticks))
custom_labels = ["Championship Team" if year == z else str(year) for year in custom_ticks]

plt.xticks(custom_ticks, custom_labels, rotation=45, ha='right', fontsize=9)

plt.tight_layout()
plt.show()

# %%
z_cmp = 24.1
z_att = 37.5
cmp_2020=22.6
cmp_2021=21.5
cmp_2022=19.3
cmp_2023=23.8
cmp_2024=18.1
ou_cmp_avg=(cmp_2020+cmp_2021+cmp_2022+cmp_2023+cmp_2024)/5
print('The avergae of OUs passing completions is', round(ou_cmp_avg, 1), 'compared to to the championship teams of', z_cmp, 'which is about 3% lower than the championship team.')
# Out:
# The avergae of OUs passing completions is 21.1 compared to to the championship teams of 24.1 which is about 3% lower than the championship team.

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('Pass Completion vs Avg Pass Yards:Game.csv')

# Championship team year and value (z)
z = 2019
champ_cmp = 24.1
champ_avg_pass = 330

# Getting the 2020–2024 average and setting it as 2018
avg_cmp_2018 = df['Cpm'].mean()
avg_pass_2018 = df['Avg_Pass/Game'].mean()
year_2018 = 2018

# Creating 2 sub plots (wider for better spacing)
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8), sharex=True)  # 🔧 widened figure

# --- Top plot ---
ax1.plot(df['Year'], df['Avg_Pass/Game'], marker='o', label='Avg Pass Yards/Game')

# 2019 championship team point
ax1.plot([z], [champ_avg_pass], marker='o', color='maroon', label='Championship Team (2019)')
ax1.axhline(y=champ_avg_pass, color='maroon', linestyle='--', linewidth=1)

# 2018 average point
ax1.plot([year_2018], [avg_pass_2018], marker='o', color='black', label='Avg of 2020–2024 (2018)')
ax1.axhline(y=avg_pass_2018, color='black', linestyle='--', linewidth=1)

ax1.set_title('Average Passing Yards per Game (2020–2024)')
ax1.set_ylabel('Yards per Game')
ax1.set_ylim(0, 400)
ax1.grid(True)
ax1.tick_params(top=False, labelbottom=True)
ax1.legend(fontsize=10)

#Bottom Plot
ax2.plot(df['Year'], df['Cpm'], marker='o', label='Completions per Game', color='darkblue')

# 2019 championship team point
ax2.plot([z], [champ_cmp], marker='o', color='maroon', label='Championship Team (2019)')
ax2.axhline(y=champ_cmp, color='maroon', linestyle='--', linewidth=1)

# 2018 average point
ax2.plot([year_2018], [avg_cmp_2018], marker='o', color='black', label='Avg of 2020–2024 (2018)')
ax2.axhline(y=avg_cmp_2018, color='black', linestyle='--', linewidth=1)

ax2.set_title('Completions per Game (2020–2024)')
ax2.set_xlabel('Year')
ax2.set_ylabel('Completions')
ax2.set_ylim(0, 40)
ax2.grid(True)
ax2.tick_params(top=False)
ax2.legend(fontsize=10)

plt.subplots_adjust(hspace=0.8, bottom=0.2)

#Custom x-axis labels
custom_ticks = list(df['Year']) + [2018, 2019]
custom_ticks = sorted(set(custom_ticks))

custom_labels = []
for year in custom_ticks:
    if year == 2019:
        custom_labels.append("Championship Team")
    elif year == 2018:
        custom_labels.append("2020–2024 Avg")
    else:
        custom_labels.append(str(year))

#Applying custom tiks to both graphs
ax1.set_xticks(custom_ticks)
ax1.set_xticklabels(custom_labels, rotation=60, ha='right', fontsize=9)

ax2.set_xticks(custom_ticks)
ax2.set_xticklabels(custom_labels, rotation=60, ha='right', fontsize=9)

plt.show()

# %%
import pandas as pd
import os

# Name of your CSV file
filename = 'OU defense rushing.csv'

# Check if the file exists
if os.path.exists(filename):
    print(f"✅ Found the file: {filename}")

    # Try loading the file
    try:
        df = pd.read_csv(filename, index_col=0)
        print("✅ Successfully loaded the CSV file!\n")
        print("Preview of the data:")
        print(df.head())
    except Exception as e:
        print("❌ Error reading the file:")
        print(e)

else:
    print(f"❌ File not found: {filename}")
    print("Make sure it's in the same folder as this Python script.")
# Out:
# ✅ Found the file: OU defense rushing.csv
# ✅ Successfully loaded the CSV file!
#
# Preview of the data:
#        att   yrds  avg_yards_att
# year
# 2014  35.2  106.4            3.0
# 2015  42.5  161.7            3.8
# 2016  35.8  162.6            4.5
# 2017  35.8  156.4            4.4
# 2018  39.1  159.8            4.1

# %%
# I wasn't sure how to label the y-axis for the 1st plot and last plot. The only thing I could think to do is to make all graphs seperate having their own independent y-axis

import matplotlib.pyplot as plt
import pandas as pd

df=pd.read_csv('Total Defense.csv')
fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(5, 1, figsize=(10, 15))

#First Plot
ax1.plot(df['year'], df['g'], marker='o', label='Games Played') #this line and one below are what you want plotted
ax1.plot(df['year'], df['yds/play'], marker='o', label='Yards per Play')

ax1.set_title('Yearly Average of Total Games Played & Yards Per Play Across all CFB Teams', fontsize=15)
ax1.set_xticks(df['year']) #doing this code plots year on each tick for each graph you have this code on
ax1.grid(True)
ax1.tick_params(top=False, labelsize=15)
ax1.legend(fontsize=10)


#Second Plot
ax2.plot(df['year'], df['yds'], marker='o', label='Total Yards', color='red')

#Making OUs 10yr Avg point & Horiz line
ou_avg_x = 2020
ou_avg_y = 4626

ax2.plot(ou_avg_x, ou_avg_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax2.axhline(y=ou_avg_y, linestyle='--', color='deepskyblue', linewidth=1)

# Adding OUs 10yr Avg x-tick
xticks = list(df['year']) + [ou_avg_x]
xtick_labels = list(df['year'].astype(str)) + ['OU avg']
ax2.set_xticks(xticks)
ax2.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

ax2.set_title('Yearly Average of Total Yards Across all CFB Team', fontsize=15)
ax2.set_ylabel('Total Yards', fontsize=15)
ax2.grid(True)
ax2.tick_params(top=False, labelsize=15)
ax2.legend(fontsize=10)



#Third Plot
ax3.plot(df['year'], df['plays'], marker='o', label='Total Plays', color='darkblue')

ax3.set_title('Yearly Average of Total Plays Across all CFB Teams', fontsize=15)
ax3.set_ylabel('Total Plays', fontsize=15)
ax3.set_xticks(df['year'])
ax3.grid(True)
ax3.tick_params(top=False, labelsize=15)
ax3.legend(fontsize=10)


#Forth Plot
ax4.plot(df['year'], df['ypg'], marker='o', label='Total Yards per Play', color='purple')

ax4.set_title('Yearly Average of Total Yards per Play Across all CFB Teams', fontsize=15)
ax4.set_ylabel('Total Yards / Play', fontsize=15)
ax4.set_xticks(df['year'])
ax4.grid(True)
ax4.tick_params(top=False, labelsize=15)
ax4.legend(fontsize=10)


#Fith Plot
ax5.plot(df['year'], df['off TDs'], marker='o', label='Total Touchdowns', color='green')
ax5.plot(df['year'], df['opp TDs'], marker='o', label='Total Opponent Touchdowns', color='yellow')

ax5.set_title('Yearly Average of Total Touchdowns & Opp Touchdowns Across all CFB Teams', fontsize=15)
ax5.set_xticks(df['year'])
ax5.grid(True)
ax5.tick_params(top=False, labelsize=15)
ax5.legend(fontsize=10)

plt.tight_layout()
plt.subplots_adjust(hspace=0.6) #changes the spacing between graphs
plt.show()
