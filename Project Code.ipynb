# %%
import numpy as np
import matplotlib as plt
import pandas as pd

# %%
#Setting up plot

fontsize = 20
figsize = (10,7)

# Configure parameters
plt.rcParams.update({'font.size': fontsize, 'figure.figsize': figsize})

# Set default tick and axes properties
plt.rcParams['xtick.labelsize'] = fontsize
plt.rcParams['ytick.labelsize'] = fontsize
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.rcParams['xtick.major.size'] = 8
plt.rcParams['ytick.major.size'] = 8
plt.rcParams['xtick.major.width'] = 4
plt.rcParams['ytick.major.width'] = 4
plt.rcParams['xtick.minor.size'] = 6
plt.rcParams['ytick.minor.size'] = 6
plt.rcParams['xtick.minor.width'] = 2
plt.rcParams['ytick.minor.width'] = 2
plt.rcParams['xtick.top'] = True
plt.rcParams['ytick.right'] = True
plt.rcParams['axes.linewidth'] = 3

# %%
import pandas as pd
import os

# Name of your CSV file
filename = 'OU defense rushing.csv'

# Check if the file exists
if os.path.exists(filename):
    print(f"✅ Found the file: {filename}")

    # Try loading the file
    try:
        df = pd.read_csv(filename, index_col=0)
        print("✅ Successfully loaded the CSV file!\n")
        print("Preview of the data:")
        print(df.head())
    except Exception as e:
        print("❌ Error reading the file:")
        print(e)

else:
    print(f"❌ File not found: {filename}")
    print("Make sure it's in the same folder as this Python script.")
# Out:
# ✅ Found the file: OU defense rushing.csv
# ✅ Successfully loaded the CSV file!
#
# Preview of the data:
#        att   yrds  avg_yards_att
# year
# 2014  35.2  106.4            3.0
# 2015  42.5  161.7            3.8
# 2016  35.8  162.6            4.5
# 2017  35.8  156.4            4.4
# 2018  39.1  159.8            4.1

# %% [markdown]
# **Over the course of 10 years, you wil see the statistics for Oklahoma, NCAA title winner, Oklahoma average of specific stat over ten years and the average of a specific stat for every college football team year by year**

# %%
import matplotlib.pyplot as plt
import pandas as pd

df=pd.read_csv('Total Defense.csv')
fig, (ax1, ax2, ax3, ax4, ax5, ax6, ax7) = plt.subplots(7, 1, figsize=(10, 30))

#--------------------------------------------------------------------------------------------------------------------------------------------------#

#First graph

ax1.plot(df['year'], df['yds/play'], color='orange',  marker='o', label=' Avg Yards Per Play')

ou_ypp_x=2020
ou_ypp_y=5.512

ax1.plot(ou_ypp_x, ou_ypp_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax1.axhline(y=ou_ypp_y, linestyle='--', color='deepskyblue', linewidth=1)

xticks = list(df['year']) + [ou_ypp_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax1.set_xticks(xticks)
ax1.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp=np.array([4.98, 4.30, 4.63, 3.99, 4.19, 5.11, 4.16, 4.88, 4.28, 4.19])
ax1.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear=np.array([5.14, 4.79, 5.85, 5.84, 6.13, 5.63, 5.73, 5.75, 5.41, 4.94])
ax1.plot(df['year'], OUyear, color='pink', marker='o', label='Oklahoma')

ax1.set_title('Yearly Average of Yards Per Play Across all CFB Teams', fontsize=15)
ax1.set_ylim(bottom=4, top=7)
ax1.set_ylabel('Avg Yards Per Play', fontsize=15)
ax1.grid(True)
ax1.tick_params(top=False, labelsize=15)
ax1.legend(fontsize=6, loc='upper right')
plt.subplots_adjust(hspace=1)

#--------------------------------------------------------------------------------------------------------------------------------------------------#

#Second Plot

ax2.plot(df['year'], df['yds'], marker='o', label='Avg Total Yards', color='orange')

ou_avg_x = 2020
ou_avg_y = 4626
ax2.plot(ou_avg_x, ou_avg_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax2.axhline(y=ou_avg_y, linestyle='--', color='deepskyblue', linewidth=1)

xticks = list(df['year']) + [ou_avg_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax2.set_xticks(xticks)
ax2.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp=np.array([5136, 4145, 4672, 3646, 4288, 5153, 4034, 4452, 3705, 4074])
ax2.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear=np.array([4974, 4738, 5616, 5529, 6353, 4990, 5080, 5993, 5062, 4137])
ax2.plot(df['year'], OUyear, color='pink', marker='o', label='Oklahoma')

ax2.set_title('Yearly Average of Total Yards Across all CFB Team', fontsize=15)
ax2.set_ylabel('Total Yards', fontsize=15)
ax2.grid(True)
ax2.tick_params(top=False, labelsize=15)
ax2.legend(fontsize=7)
plt.subplots_adjust(hspace=1)

#--------------------------------------------------------------------------------------------------------------------------------------------------#

#Third graph

ax3.plot(df['year'], df['plays'], marker='o', label='Total Plays', color='orange')

ou_avg_x = 2020
ou_avg_y = 949
ax3.plot(ou_avg_x, ou_avg_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax3.axhline(y=ou_avg_y, linestyle='--', color='deepskyblue', linewidth=1)

xticks = list(df['year']) + [ou_avg_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax3.set_xticks(xticks)
ax3.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp=np.array([1032, 963, 1008, 913, 1023, 1008, 970, 912, 865, 972])
ax3.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear=np.array([968, 989, 960, 947, 1036, 886, 887, 1043, 943, 837])
ax3.plot(df['year'], OUyear, color='pink', marker='o', label='Oklahoma')

ax3.set_title('Yearly Average of Total Plays Across all CFB Team', fontsize=15)
ax3.set_ylabel('Total Plays', fontsize=15)
ax3.grid(True)
ax3.tick_params(top=False, labelsize=15)
ax3.legend(fontsize=7)
#--------------------------------------------------------------------------------------------------------------------------------------------------#

#Forth Plot

ax4.plot(df['year'], df['ypg'], marker='o', label='Avg Yards Per Game', color='orange')

ou_avg_x = 2020
ou_avg_y = 394
ax4.plot(ou_avg_x, ou_avg_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax4.axhline(y=ou_avg_y, linestyle='--', color='deepskyblue', linewidth=1)

xticks = list(df['year']) + [ou_avg_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax4.set_xticks(xticks)
ax4.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp=np.array([342.4, 276.3, 311.5, 260.4, 285.9, 343.5, 268.9, 296.8, 247, 254.6])
ax4.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear=np.array([382.6, 364.5, 432, 394.9, 453.8, 356.4, 390.8, 461, 389.4, 318.2])
ax4.plot(df['year'], OUyear, color='pink', marker='o', label='Oklahoma')

ax4.set_title('Yearly Average of Total Yards Per Game Across all CFB Team', fontsize=15)
ax4.set_ylabel('Avg Total Yards Per Game', fontsize=15)
ax4.grid(True)
ax4.tick_params(top=False, labelsize=15)
ax4.legend(fontsize=7)

#--------------------------------------------------------------------------------------------------------------------------------------------------#

#Fith Plot

ax5.plot(df['year'], df['opp TDs'], marker='o', label='Avg Total Opp TDs', color='orange')

ou_avg_x = 2020
ou_avg_y = 43
ax5.plot(ou_avg_x, ou_avg_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax5.axhline(y=ou_avg_y, linestyle='--', color='deepskyblue', linewidth=1)

xticks = list(df['year']) + [ou_avg_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax5.set_xticks(xticks)
ax5.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp=np.array([43, 26, 34, 18, 23, 42, 16, 23, 17, 24])
ax5.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear=np.array([43, 37, 46, 47, 62, 48, 43, 49, 35, 33])
ax5.plot(df['year'], OUyear, color='pink', marker='o', label='Oklahoma')

ax5.set_title('Yearly Average of Opp TDs Across all CFB Team', fontsize=15)
ax5.set_ylabel('Avg Opp TDs', fontsize=15)
ax5.grid(True)
ax5.tick_params(top=False, labelsize=15)
ax5.legend(fontsize=6)

#--------------------------------------------------------------------------------------------------------------------------------------------------#

#Sixth Plot

ax6.plot(df['year'], df['sacks'], marker='o', label='Total Sacks', color='orange')

ou_avg_x = 2020
ou_avg_y = 30.7
ax6.plot(ou_avg_x, ou_avg_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax6.axhline(y=ou_avg_y, linestyle='--', color='deepskyblue', linewidth=1)

xticks = list(df['year']) + [ou_avg_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax6.set_xticks(xticks)
ax6.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp=np.array([45, 53, 49, 40, 54, 24, 49, 35, 39, 53])
ax6.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear=np.array([32, 40, 25, 26, 28, 36, 33, 28, 24, 35])
ax6.plot(df['year'], OUyear, color='pink', marker='o', label='Oklahoma')

ax6.set_title('Yearly Average of Sacks Across all CFB Team', fontsize=15)
ax6.set_ylabel('Avg Sacks', fontsize=15)
ax6.grid(True)
ax6.tick_params(top=False, labelsize=15)
ax6.legend(fontsize=7)

#--------------------------------------------------------------------------------------------------------------------------------------------------#

#Seventh Plot

ax7.plot(df['year'], df['turn gain'], marker='o', label='Total Sacks', color='orange')

ou_avg_x = 2020
ou_avg_y = 205.9
ax7.plot(ou_avg_x, ou_avg_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax7.axhline(y=ou_avg_y, linestyle='--', color='deepskyblue', linewidth=1)

xticks = list(df['year']) + [ou_avg_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax7.set_xticks(xticks)
ax7.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp=np.array([307, 337, 322, 274, 318, 163, 389, 231, 301, 362])
ax7.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear=np.array([226, 243, 153, 195, 181, 253, 214, 211, 165, 218])
ax7.plot(df['year'], OUyear, color='pink', marker='o', label='Oklahoma')

ax7.set_title('Yearly Average of Sacks Across all CFB Team', fontsize=15)
ax7.set_ylabel('Avg Sacks Yards For Loss', fontsize=15)
ax7.grid(True)
ax7.tick_params(top=False, labelsize=15)
ax7.legend(fontsize=7)

plt.tight_layout()
plt.subplots_adjust(hspace=1)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

df=pd.read_csv('Turnover margin.csv')
fig, (ax1, ax2, ax3, ax4, ax5, ax6) = plt.subplots(6, 1, figsize=(10, 30))

#----------------------------------------------------------------------------------------------------------------------------------------------#

#First graph

ax1.plot(df['year'], df['fum rec'], color='orange',  marker='o', label='Fumbles Recovered')

ou_ypp_x=2020
ou_ypp_y=7.6

ax1.plot(ou_ypp_x, ou_ypp_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax1.axhline(y=ou_ypp_y, linestyle='--', color='deepskyblue', linewidth=1)

xticks = list(df['year']) + [ou_ypp_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax1.set_xticks(xticks)
ax1.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp=np.array([8, 8, 7, 5, 12, 5, 5, 7, 9, 9])
ax1.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear=np.array([7, 7, 8, 10, 5, 4, 13, 4, 6, 12])
ax1.plot(df['year'], OUyear, color='pink', marker='o', label='Oklahoma')

ax1.set_title('Yearly Average of Fumbles Recovered Across all CFB Teams', fontsize=15)
ax1.set_ylabel('Avg Fumbles Recovered', fontsize=15)
ax1.grid(True)
ax1.tick_params(top=False, labelsize=15)
ax1.legend(fontsize=6, loc='upper right')
plt.subplots_adjust(hspace=1)

#----------------------------------------------------------------------------------------------------------------------------------------------#

#Second graph

ax2.plot(df['year'], df['opp int'], color='orange',  marker='o', label=' Avg Opponent Interceptions')

ou_ypp_x=2020
ou_ypp_y=11.9

ax2.plot(ou_ypp_x, ou_ypp_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax2.axhline(y=ou_ypp_y, linestyle='--', color='deepskyblue', linewidth=1)

xticks = list(df['year']) + [ou_ypp_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax2.set_xticks(xticks)
ax2.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp=np.array([25, 19, 20, 19, 12, 17, 16, 12, 18, 10])
ax2.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear=np.array([12, 20, 9, 8, 6, 7, 11, 17, 20, 9])
ax2.plot(df['year'], OUyear, color='pink', marker='o', label='Oklahoma')

ax2.set_title('Yearly Average of Opponent Interceptions Across all CFB Teams', fontsize=15)
ax2.set_ylabel('Avg Opponent Interceptions', fontsize=15)
ax2.grid(True)
ax2.tick_params(top=False, labelsize=15)
ax2.legend(fontsize=6, loc='upper right')
plt.subplots_adjust(hspace=1)

#----------------------------------------------------------------------------------------------------------------------------------------------#

#Third graph

ax3.plot(df['year'], df['turn gain'], color='orange',  marker='o', label=' Avg Yardage Gained on Turnovers')

ou_ypp_x=2020
ou_ypp_y=19.5

ax3.plot(ou_ypp_x, ou_ypp_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax3.axhline(y=ou_ypp_y, linestyle='--', color='deepskyblue', linewidth=1)

xticks = list(df['year']) + [ou_ypp_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax3.set_xticks(xticks)
ax3.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp=np.array([33, 27, 27, 24, 24, 22, 21, 19, 27, 19])
ax3.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear=np.array([19, 27, 17, 18, 11, 11, 24, 21, 26, 21])
ax3.plot(df['year'], OUyear, color='pink', marker='o', label='Oklahoma')

ax3.set_title('Yearly Avg Yardage Gained on Turnovers Across all CFB Teams', fontsize=15)
ax3.set_ylabel('Avg Yardage Gained on Turnovers', fontsize=15)
ax3.grid(True)
ax3.tick_params(top=False, labelsize=15)
ax3.legend(fontsize=6, loc='upper right')
plt.subplots_adjust(hspace=1)

#----------------------------------------------------------------------------------------------------------------------------------------------#

#Fourth graph

ax4.plot(df['year'], df['fum lost'], color='orange',  marker='o', label=' Avg Fumbles Lost')

ou_ypp_x=2020
ou_ypp_y=8.9

ax4.plot(ou_ypp_x, ou_ypp_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax4.axhline(y=ou_ypp_y, linestyle='--', color='deepskyblue', linewidth=1)

xticks = list(df['year']) + [ou_ypp_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax4.set_xticks(xticks)
ax4.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp=np.array([14, 7, 11, 7, 9, 5, 6, 11, 3, 6])
ax4.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear=np.array([7, 9, 9, 7, 6, 9, 9, 7, 11, 15])
ax4.plot(df['year'], OUyear, color='pink', marker='o', label='Oklahoma')

ax4.set_title('Yearly Avg Fumbles Lost Across all CFB Teams', fontsize=15)
ax4.set_ylabel('Avg Fumbles Lost', fontsize=15)
ax4.grid(True)
ax4.tick_params(top=False, labelsize=15)
ax4.legend(fontsize=6, loc='upper right')
plt.subplots_adjust(hspace=1)

#----------------------------------------------------------------------------------------------------------------------------------------------#

#Fith graph

ax5.plot(df['year'], df['int'], color='orange',  marker='o', label=' Avg Interceptions')

ou_ypp_x=2020
ou_ypp_y=8.8

ax5.plot(ou_ypp_x, ou_ypp_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax5.axhline(y=ou_ypp_y, linestyle='--', color='deepskyblue', linewidth=1)

xticks = list(df['year']) + [ou_ypp_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax5.set_xticks(xticks)
ax5.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp=np.array([12, 10, 17, 3, 8, 7, 12, 7, 5, 10])
ax5.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear=np.array([17, 9, 8, 6, 7, 9, 9, 8, 9, 6])
ax5.plot(df['year'], OUyear, color='pink', marker='o', label='Oklahoma')

ax5.set_title('Yearly Avg Interceptions Across all CFB Teams', fontsize=15)
ax5.set_ylabel('Avg Interceptions', fontsize=15)
ax5.grid(True)
ax5.tick_params(top=False, labelsize=15)
ax5.legend(fontsize=6, loc='upper right')
plt.subplots_adjust(hspace=1)

#----------------------------------------------------------------------------------------------------------------------------------------------#

#Sixth graph

ax6.plot(df['year'], df['turn lost'], color='orange',  marker='o', label='Avg Yardage Lost on Turnovers')

ou_ypp_x=2020
ou_ypp_y=17.3

ax6.plot(ou_ypp_x, ou_ypp_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax6.axhline(y=ou_ypp_y, linestyle='--', color='deepskyblue', linewidth=1)

xticks = list(df['year']) + [ou_ypp_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax6.set_xticks(xticks)
ax6.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp=np.array([26, 17, 28, 10, 17, 12, 18, 18, 8, 16])
ax6.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear=np.array([24, 18, 17, 13, 13, 19, 13, 15, 20, 21])
ax6.plot(df['year'], OUyear, color='pink', marker='o', label='Oklahoma')

ax6.set_title('Yearly Avg Yardage Lost on Turnovers Across all CFB Teams', fontsize=15)
ax6.set_ylabel('Avg Yardage Lost on Turnovers', fontsize=15)
ax6.grid(True)
ax6.tick_params(top=False, labelsize=15)
ax6.legend(fontsize=6, loc='upper right')
plt.subplots_adjust(hspace=1)

plt.tight_layout()
plt.subplots_adjust(hspace=1)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

df=pd.read_csv('Rushing Defense.csv')
fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(5, 1, figsize=(10, 30))

#----------------------------------------------------------------------------------------------------------------------------------------------#

#First graph

ax1.plot(df['year'], df['Opp Rush'], color='orange',  marker='o', label=' Avg Opponents Rushing')

ou_ypp_x=2020
ou_ypp_y=490.5

ax1.plot(ou_ypp_x, ou_ypp_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax1.axhline(y=ou_ypp_y, linestyle='--', color='deepskyblue', linewidth=1)

xticks = list(df['year']) + [ou_ypp_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax1.set_xticks(xticks)
ax1.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp=np.array([537, 468, 525, 487, 576, 487, 463, 401, 450, 530])
ax1.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear=np.array([458, 552, 465, 500, 548, 459, 442, 544, 461, 476])
ax1.plot(df['year'], OUyear, color='pink', marker='o', label='Oklahoma')

ax1.set_title('Yearly Average of Opponents Rushing Across all CFB Teams', fontsize=15)
ax1.set_ylabel('Avg Opponents Rushing', fontsize=15)
ax1.grid(True)
ax1.tick_params(top=False, labelsize=15)
ax1.legend(fontsize=6, loc='upper right')
plt.subplots_adjust(hspace=1)

#----------------------------------------------------------------------------------------------------------------------------------------------#

#Second Plot

ax2.plot(df['year'], df['Opp Rush Yds'], marker='o', label='Avg Opponents Rushing Yards', color='orange')

ou_avg_x = 2020
ou_avg_y = 1931.6
ax2.plot(ou_avg_x, ou_avg_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax2.axhline(y=ou_avg_y, linestyle='--', color='deepskyblue', linewidth=1)

xticks = list(df['year']) + [ou_avg_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax2.set_xticks(xticks)
ax2.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp=np.array([2120, 1136, 1944, 1326, 1444, 1812, 1183, 1156, 1350, 1402])
ax2.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear=np.array([1383, 2102, 2114, 2191, 2237, 1877, 1677, 2437, 1802, 1496])
ax2.plot(df['year'], OUyear, color='pink', marker='o', label='Oklahoma')

ax2.set_title('Yearly Average of Opponents Rushing Yards Across all CFB Team', fontsize=15)
ax2.set_ylabel('Opponents Rushing Yards', fontsize=15)
ax2.grid(True)
ax2.tick_params(top=False, labelsize=15)
ax2.legend(fontsize=7)
plt.subplots_adjust(hspace=1)

#----------------------------------------------------------------------------------------------------------------------------------------------#

#Third graph

ax3.plot(df['year'], df['Yds/Rush'], marker='o', label='Avg Yards Per Rush', color='orange')

ou_avg_x = 2020
ou_avg_y = 3.9
ax3.plot(ou_avg_x, ou_avg_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax3.axhline(y=ou_avg_y, linestyle='--', color='deepskyblue', linewidth=1)

xticks = list(df['year']) + [ou_avg_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax3.set_xticks(xticks)
ax3.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp=np.array([3.95, 2.43, 3.70, 2.72, 2.51, 3.72, 2.56, 2.88, 3.00, 2.65])
ax3.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear=np.array([3.02, 3.81, 4.55, 4.38, 4.08, 4.09, 3.79, 4.48, 3.91, 3.14])
ax3.plot(df['year'], OUyear, color='pink', marker='o', label='Oklahoma')

ax3.set_title('Yearly Average of Yards Per Rush Across all CFB Team', fontsize=15)
ax3.set_ylabel('Yards Per Rush', fontsize=15)
ax3.grid(True)
ax3.tick_params(top=False, labelsize=15)
ax3.legend(fontsize=7)
#----------------------------------------------------------------------------------------------------------------------------------------------#

#Forth Plot

ax4.plot(df['year'], df['Opp Rush TDs'], marker='o', label='Avg Opponent Rushing TDs', color='orange')

ou_avg_x = 2020
ou_avg_y = 19.1
ax4.plot(ou_avg_x, ou_avg_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax4.axhline(y=ou_avg_y, linestyle='--', color='deepskyblue', linewidth=1)

xticks = list(df['year']) + [ou_avg_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax4.set_xticks(xticks)
ax4.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp=np.array([24, 7, 20, 9, 8, 19, 3, 7, 9, 13])
ax4.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear=np.array([15, 15, 15, 24, 33, 20, 15, 29, 14, 11])
ax4.plot(df['year'], OUyear, color='pink', marker='o', label='Oklahoma')

ax4.set_title('Yearly Average of Opponent Rushing TDs Across all CFB Team', fontsize=15)
ax4.set_ylabel('Avg Total Yards Per Game', fontsize=15)
ax4.grid(True)
ax4.tick_params(top=False, labelsize=15)
ax4.legend(fontsize=7)

#----------------------------------------------------------------------------------------------------------------------------------------------#

#Fith Plot

ax5.plot(df['year'], df['YPG'], marker='o', label='Avg Yards Per Game', color='orange')

ou_avg_x = 2020
ou_avg_y = 145.1
ax5.plot(ou_avg_x, ou_avg_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax5.axhline(y=ou_avg_y, linestyle='--', color='deepskyblue', linewidth=1)

xticks = list(df['year']) + [ou_avg_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax5.set_xticks(xticks)
ax5.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp=np.array([141.3, 75.7, 129.6, 94.7, 96.3, 120.8, 78.9, 77.1, 90, 87.6])
ax5.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear=np.array([106.4, 161.7, 162.6, 156.5, 159.8, 134.1, 129, 187.5, 138.6, 115.1])
ax5.plot(df['year'], OUyear, color='pink', marker='o', label='Oklahoma')

ax5.set_title('Yearly Average of Yards Per Game Across all CFB Team', fontsize=15)
ax5.set_ylabel('Avg Yards Per Game', fontsize=15)
ax5.grid(True)
ax5.tick_params(top=False, labelsize=15)
ax5.legend(fontsize=6)

plt.tight_layout()
plt.subplots_adjust(hspace=1)
plt.show()
