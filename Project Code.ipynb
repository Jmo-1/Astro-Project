# %%
import numpy as np
import matplotlib as plt
import pandas as pd

# %%
#Setting up plot

fontsize = 20
figsize = (10,7)

# Configure parameters
plt.rcParams.update({'font.size': fontsize, 'figure.figsize': figsize})

# Set default tick and axes properties
plt.rcParams['xtick.labelsize'] = fontsize
plt.rcParams['ytick.labelsize'] = fontsize
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.rcParams['xtick.major.size'] = 6
plt.rcParams['ytick.major.size'] = 6
plt.rcParams['xtick.major.width'] = 3
plt.rcParams['ytick.major.width'] = 3
plt.rcParams['xtick.minor.size'] = 6
plt.rcParams['ytick.minor.size'] = 6
plt.rcParams['xtick.minor.width'] = 2
plt.rcParams['ytick.minor.width'] = 2
#plt.rcParams['xtick.top'] = True
#plt.rcParams['ytick.right'] = True
plt.rcParams['axes.linewidth'] = 3

# %%
import pandas as pd
import os

# Name of your CSV file
filename = 'OU defense rushing.csv'

# Check if the file exists
if os.path.exists(filename):
    print(f"✅ Found the file: {filename}")

    # Try loading the file
    try:
        df = pd.read_csv(filename, index_col=0)
        print("✅ Successfully loaded the CSV file!\n")
        print("Preview of the data:")
        print(df.head())
    except Exception as e:
        print("❌ Error reading the file:")
        print(e)

else:
    print(f"❌ File not found: {filename}")
    print("Make sure it's in the same folder as this Python script.")
# Out:
# ✅ Found the file: OU defense rushing.csv
# ✅ Successfully loaded the CSV file!
#
# Preview of the data:
#        att   yrds  avg_yards_att
# year
# 2014  35.2  106.4            3.0
# 2015  42.5  161.7            3.8
# 2016  35.8  162.6            4.5
# 2017  35.8  156.4            4.4
# 2018  39.1  159.8            4.1

# %% [markdown]
# # Total Defense
# #### This includes
# ##### - Total Plays Ran
# ##### - Total Yards
# ##### - Yards / Play
# ##### - Opponent Touchdowns (touchdowns allowed by the defense)
# ##### - Yards Allowed Per Game by Defense (YPG)
# ##### - Sacks by Defense
# ##### - Total Yardage Lost by Sacks

# %%
import matplotlib.pyplot as plt
import pandas as pd

df=pd.read_csv('Total Defense.csv')
fig, (ax1, ax2, ax3, ax4, ax5, ax6, ax7) = plt.subplots(7, 1, figsize=(10, 37))

#--------------------------------------------------------------------------------------------------------------------------------------------------#

#First graph

ax1.plot(df['year'], df['yds/play'], color='orange',  marker='o', label='Avg Yards Per Play Across all CFB Teams')

ou_ypp_x=2020
ou_ypp_y=5.512

ax1.plot(ou_ypp_x, ou_ypp_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax1.axhline(y=ou_ypp_y, linestyle='--', color='deepskyblue', linewidth=1)

xticks = list(df['year']) + [ou_ypp_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax1.set_xticks(xticks)
ax1.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp=np.array([4.98, 4.30, 4.63, 3.99, 4.19, 5.11, 4.16, 4.88, 4.28, 4.19])
ax1.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear=np.array([5.14, 4.79, 5.85, 5.84, 6.13, 5.63, 5.73, 5.75, 5.41, 4.94])
ax1.plot(df['year'], OUyear, color='maroon', marker='o', label='Oklahoma')

ax1.set_title('Yards Per Play Across 10 Years', fontsize=15, fontweight='bold')
ax1.set_ylim(bottom=4, top=7)
ax1.set_ylabel('Yards Per Play', fontsize=15, fontweight='bold')
ax1.grid(True)
ax1.tick_params(top=False, right=False, labelsize=15)
ax1.legend(fontsize=6, loc='upper right')
plt.subplots_adjust(hspace=1)

#--------------------------------------------------------------------------------------------------------------------------------------------------#

#Second Plot

ax2.plot(df['year'], df['yds'], marker='o', label='Avg Total Yards Across all CFB Teams', color='orange')

ou_avg_x = 2020
ou_avg_y = 4626
ax2.plot(ou_avg_x, ou_avg_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax2.axhline(y=ou_avg_y, linestyle='--', color='deepskyblue', linewidth=1)

xticks = list(df['year']) + [ou_avg_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax2.set_xticks(xticks)
ax2.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp=np.array([5136, 4145, 4672, 3646, 4288, 5153, 4034, 4452, 3705, 4074])
ax2.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear=np.array([4974, 4738, 5616, 5529, 6353, 4990, 5080, 5993, 5062, 4137])
ax2.plot(df['year'], OUyear, color='maroon', marker='o', label='Oklahoma')

ax2.set_title('Total Yards Across 10 Years', fontsize=15, fontweight='bold')
ax2.set_ylabel('Total Yards', fontsize=15, fontweight='bold')
ax2.grid(True)
ax2.tick_params(top=False, right=False, labelsize=15)
ax2.legend(fontsize=7)
plt.subplots_adjust(hspace=1)

#--------------------------------------------------------------------------------------------------------------------------------------------------#

#Third graph

ax3.plot(df['year'], df['plays'], marker='o', label='Avg Total Plays Across all CFB Teams', color='orange')

ou_avg_x = 2020
ou_avg_y = 949
ax3.plot(ou_avg_x, ou_avg_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax3.axhline(y=ou_avg_y, linestyle='--', color='deepskyblue', linewidth=1)

xticks = list(df['year']) + [ou_avg_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax3.set_xticks(xticks)
ax3.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp=np.array([1032, 963, 1008, 913, 1023, 1008, 970, 912, 865, 972])
ax3.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear=np.array([968, 989, 960, 947, 1036, 886, 887, 1043, 943, 837])
ax3.plot(df['year'], OUyear, color='maroon', marker='o', label='Oklahoma')

ax3.set_title('Total Plays Across 10 Years', fontsize=15, fontweight='bold')
ax3.set_ylabel('Total Plays', fontsize=15, fontweight='bold')
ax3.grid(True)
ax3.tick_params(top=False, right=False, labelsize=15)
ax3.legend(fontsize=7)
#--------------------------------------------------------------------------------------------------------------------------------------------------#

#Forth Plot

ax4.plot(df['year'], df['ypg'], marker='o', label='Avg Yards Per Game Across all CFB Teams', color='orange')

ou_avg_x = 2020
ou_avg_y = 394
ax4.plot(ou_avg_x, ou_avg_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax4.axhline(y=ou_avg_y, linestyle='--', color='deepskyblue', linewidth=1)

xticks = list(df['year']) + [ou_avg_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax4.set_xticks(xticks)
ax4.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp=np.array([342.4, 276.3, 311.5, 260.4, 285.9, 343.5, 268.9, 296.8, 247, 254.6])
ax4.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear=np.array([382.6, 364.5, 432, 394.9, 453.8, 356.4, 390.8, 461, 389.4, 318.2])
ax4.plot(df['year'], OUyear, color='maroon', marker='o', label='Oklahoma')

ax4.set_title('Total Yards Per Game Across 10 Years', fontsize=15, fontweight='bold')
ax4.set_ylabel('Total Yards Per Game', fontsize=15, fontweight='bold')
ax4.grid(True)
ax4.tick_params(top=False, right=False, labelsize=15)
ax4.legend(fontsize=7)

#--------------------------------------------------------------------------------------------------------------------------------------------------#

#Fith Plot

ax5.plot(df['year'], df['opp TDs'], marker='o', label='Avg Total Opp TDs Across all CFB Teams', color='orange')

ou_avg_x = 2020
ou_avg_y = 43
ax5.plot(ou_avg_x, ou_avg_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax5.axhline(y=ou_avg_y, linestyle='--', color='deepskyblue', linewidth=1)

xticks = list(df['year']) + [ou_avg_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax5.set_xticks(xticks)
ax5.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp=np.array([43, 26, 34, 18, 23, 42, 16, 23, 17, 24])
ax5.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear=np.array([43, 37, 46, 47, 62, 48, 43, 49, 35, 33])
ax5.plot(df['year'], OUyear, color='maroon', marker='o', label='Oklahoma')

ax5.set_title('Opponent TDs Across 10 Years', fontsize=15, fontweight='bold')
ax5.set_ylabel('Opponent TDs', fontsize=15, fontweight='bold')
ax5.grid(True)
ax5.tick_params(top=False, right=False, labelsize=15)
ax5.legend(fontsize=6)

#--------------------------------------------------------------------------------------------------------------------------------------------------#

#Sixth Plot

ax6.plot(df['year'], df['sacks'], marker='o', label='Avg Total Sacks Across all CFB Teams', color='orange')

ou_avg_x = 2020
ou_avg_y = 30.7
ax6.plot(ou_avg_x, ou_avg_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax6.axhline(y=ou_avg_y, linestyle='--', color='deepskyblue', linewidth=1)

xticks = list(df['year']) + [ou_avg_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax6.set_xticks(xticks)
ax6.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp=np.array([45, 53, 49, 40, 54, 24, 49, 35, 39, 53])
ax6.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear=np.array([32, 40, 25, 26, 28, 36, 33, 28, 24, 35])
ax6.plot(df['year'], OUyear, color='maroon', marker='o', label='Oklahoma')

ax6.set_title('Sacks Across 10 Years', fontsize=15, fontweight='bold')
ax6.set_ylabel('Sacks', fontsize=15, fontweight='bold')
ax6.grid(True)
ax6.tick_params(top=False, right=False, labelsize=15)
ax6.legend(fontsize=7)

#--------------------------------------------------------------------------------------------------------------------------------------------------#

#Seventh Plot

ax7.plot(df['year'], df['sack yrds'], marker='o', label='Avg Total Sacked Yards For Loss Across all CFB Teams', color='orange')

ou_avg_x = 2020
ou_avg_y = 205.9
ax7.plot(ou_avg_x, ou_avg_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax7.axhline(y=ou_avg_y, linestyle='--', color='deepskyblue', linewidth=1)

xticks = list(df['year']) + [ou_avg_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax7.set_xticks(xticks)
ax7.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp=np.array([307, 337, 322, 274, 318, 163, 389, 231, 301, 362])
ax7.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear=np.array([226, 243, 153, 195, 181, 253, 214, 211, 165, 218])
ax7.plot(df['year'], OUyear, color='maroon', marker='o', label='Oklahoma')

ax7.set_title('Total Sacked Yards For Loss Across 10 Years', fontsize=15, fontweight='bold')
ax7.set_ylabel('Sacks Yards For Loss', fontsize=15, fontweight='bold')
ax7.grid(True)
ax7.tick_params(top=False, right=False, labelsize=15)
ax7.legend(fontsize=7)

plt.tight_layout()
plt.subplots_adjust(hspace=0.3)
plt.show()

# %% [markdown]
# # Turnover Margin
# #### This includes
# ##### - Fumbles Recovered by Defense
# ##### - Opponent Interceptions
# ##### - Yardage Gained on Turnovers
# ##### - Fumbles Not Recovered
# ##### - Interceptions Made by Defense
# ##### - Yardage Lost on Turnovers

# %%
import matplotlib.pyplot as plt
import pandas as pd

df=pd.read_csv('Turnover margin.csv')
fig, (ax1, ax2, ax3, ax4, ax5, ax6) = plt.subplots(6, 1, figsize=(10, 38))

#----------------------------------------------------------------------------------------------------------------------------------------------#

#First graph

ax1.plot(df['year'], df['fum rec'], color='orange',  marker='o', label='Avg Fumbles Recovered Across all CFB Teams')

ou_ypp_x=2020
ou_ypp_y=7.6

ax1.plot(ou_ypp_x, ou_ypp_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax1.axhline(y=ou_ypp_y, linestyle='--', color='deepskyblue', linewidth=1)

xticks = list(df['year']) + [ou_ypp_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax1.set_xticks(xticks)
ax1.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp=np.array([8, 8, 7, 5, 12, 5, 5, 7, 9, 9])
ax1.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear=np.array([7, 7, 8, 10, 5, 4, 13, 4, 6, 12])
ax1.plot(df['year'], OUyear, color='maroon', marker='o', label='Oklahoma')

ax1.set_title('Fumbles Recovered Across 10 Years', fontsize=15, fontweight='bold')
ax1.set_ylabel('Fumbles Recovered', fontsize=15, fontweight='bold')
ax1.grid(True)
ax1.tick_params(top=False, right=False, labelsize=15)
ax1.legend(fontsize=6, loc='upper right')
plt.subplots_adjust(hspace=0.3)

#----------------------------------------------------------------------------------------------------------------------------------------------#

#Second graph

ax2.plot(df['year'], df['opp int'], color='orange',  marker='o', label='Avg Opponent Interceptions Across all CFB Teams')

ou_ypp_x=2020
ou_ypp_y=11.9

ax2.plot(ou_ypp_x, ou_ypp_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax2.axhline(y=ou_ypp_y, linestyle='--', color='deepskyblue', linewidth=1)

xticks = list(df['year']) + [ou_ypp_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax2.set_xticks(xticks)
ax2.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp=np.array([25, 19, 20, 19, 12, 17, 16, 12, 18, 10])
ax2.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear=np.array([12, 20, 9, 8, 6, 7, 11, 17, 20, 9])
ax2.plot(df['year'], OUyear, color='maroon', marker='o', label='Oklahoma')

ax2.set_title('Opponent Interceptions Across 10 Years', fontsize=15, fontweight='bold')
ax2.set_ylabel('Opponent Interceptions', fontsize=15, fontweight='bold')
ax2.grid(True)
ax2.tick_params(top=False, right=False, labelsize=15)
ax2.legend(fontsize=6, loc='upper right')
plt.subplots_adjust(hspace=0.3)

#----------------------------------------------------------------------------------------------------------------------------------------------#

#Third graph

ax3.plot(df['year'], df['turn gain'], color='orange',  marker='o', label='Avg Yardage Gained on Turnovers Across all CFB Teams')

ou_ypp_x=2020
ou_ypp_y=19.5

ax3.plot(ou_ypp_x, ou_ypp_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax3.axhline(y=ou_ypp_y, linestyle='--', color='deepskyblue', linewidth=1)

xticks = list(df['year']) + [ou_ypp_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax3.set_xticks(xticks)
ax3.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp=np.array([33, 27, 27, 24, 24, 22, 21, 19, 27, 19])
ax3.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear=np.array([19, 27, 17, 18, 11, 11, 24, 21, 26, 21])
ax3.plot(df['year'], OUyear, color='maroon', marker='o', label='Oklahoma')

ax3.set_title('Yardage Gained on Turnovers Across 10 Years', fontsize=15, fontweight='bold')
ax3.set_ylabel('Yardage Gained on Turnovers', fontsize=15, fontweight='bold')
ax3.grid(True)
ax3.tick_params(top=False, right=False, labelsize=15)
ax3.legend(fontsize=6, loc='upper right')
plt.subplots_adjust(hspace=0.3)

#----------------------------------------------------------------------------------------------------------------------------------------------#

#Fourth graph

ax4.plot(df['year'], df['fum lost'], color='orange',  marker='o', label='Avg Fumbles Lost Across all CFB Teams')

ou_ypp_x=2020
ou_ypp_y=8.9

ax4.plot(ou_ypp_x, ou_ypp_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax4.axhline(y=ou_ypp_y, linestyle='--', color='deepskyblue', linewidth=1)

xticks = list(df['year']) + [ou_ypp_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax4.set_xticks(xticks)
ax4.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp=np.array([14, 7, 11, 7, 9, 5, 6, 11, 3, 6])
ax4.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear=np.array([7, 9, 9, 7, 6, 9, 9, 7, 11, 15])
ax4.plot(df['year'], OUyear, color='maroon', marker='o', label='Oklahoma')

ax4.set_title('Fumbles Lost Across 10 Years', fontsize=15, fontweight='bold')
ax4.set_ylabel('Fumbles Lost', fontsize=15, fontweight='bold')
ax4.grid(True)
ax4.tick_params(top=False, right=False, labelsize=15)
ax4.legend(fontsize=6, loc='upper right')
plt.subplots_adjust(hspace=0.3)

#----------------------------------------------------------------------------------------------------------------------------------------------#

#Fith graph

ax5.plot(df['year'], df['int'], color='orange',  marker='o', label='Avg Interceptions Across all CFB Teams')

ou_ypp_x=2020
ou_ypp_y=8.8

ax5.plot(ou_ypp_x, ou_ypp_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax5.axhline(y=ou_ypp_y, linestyle='--', color='deepskyblue', linewidth=1)

xticks = list(df['year']) + [ou_ypp_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax5.set_xticks(xticks)
ax5.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp=np.array([12, 10, 17, 3, 8, 7, 12, 7, 5, 10])
ax5.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear=np.array([17, 9, 8, 6, 7, 9, 9, 8, 9, 6])
ax5.plot(df['year'], OUyear, color='maroon', marker='o', label='Oklahoma')

ax5.set_title('Interceptions Across 10 Years', fontsize=15, fontweight='bold')
ax5.set_ylabel('Interceptions', fontsize=15, fontweight='bold')
ax5.grid(True)
ax5.tick_params(top=False, right=False, labelsize=15)
ax5.legend(fontsize=6, loc='upper right')
plt.subplots_adjust(hspace=0.3)

#----------------------------------------------------------------------------------------------------------------------------------------------#

#Sixth graph

ax6.plot(df['year'], df['turn lost'], color='orange',  marker='o', label='Avg Yardage Lost on Turnovers Across all CFB Teams')

ou_ypp_x=2020
ou_ypp_y=17.3

ax6.plot(ou_ypp_x, ou_ypp_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax6.axhline(y=ou_ypp_y, linestyle='--', color='deepskyblue', linewidth=1)

xticks = list(df['year']) + [ou_ypp_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax6.set_xticks(xticks)
ax6.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp=np.array([26, 17, 28, 10, 17, 12, 18, 18, 8, 16])
ax6.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear=np.array([24, 18, 17, 13, 13, 19, 13, 15, 20, 21])
ax6.plot(df['year'], OUyear, color='maroon', marker='o', label='Oklahoma')

ax6.set_title('Yardage Lost on Turnovers Across 10 Years', fontsize=15, fontweight='bold')
ax6.set_ylabel('Yardage Lost on Turnovers', fontsize=15, fontweight='bold')
ax6.grid(True)
ax6.tick_params(top=False, right=False, labelsize=15)
ax6.legend(fontsize=6, loc='upper right')
plt.subplots_adjust(hspace=1)

plt.tight_layout()
plt.subplots_adjust(hspace=0.3)
plt.show()

# %% [markdown]
# # Rushing Defense
# #### This includes
# ##### - Total Yardage Allowed vs Rushing Attempt
# ##### - Rushing Yardage Allowed by Defense
# ##### - Yards Gained Per Rush Allowed by Defense
# ##### - Rushing Touchdowns Allowed by Defense
# ##### - Yards Per Game Allowed by Defense

# %%
import matplotlib.pyplot as plt
import pandas as pd

df=pd.read_csv('Rushing Defense.csv')
fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(5, 1, figsize=(10, 32))

#----------------------------------------------------------------------------------------------------------------------------------------------#

#First graph

ax1.plot(df['year'], df['Opp Rush'], color='orange',  marker='o', label=' Avg Opponents Rushing Across all CFB Teams')

ou_ypp_x=2020
ou_ypp_y=490.5

ax1.plot(ou_ypp_x, ou_ypp_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax1.axhline(y=ou_ypp_y, linestyle='--', color='deepskyblue', linewidth=1)

xticks = list(df['year']) + [ou_ypp_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax1.set_xticks(xticks)
ax1.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp=np.array([537, 468, 525, 487, 576, 487, 463, 401, 450, 530])
ax1.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear=np.array([458, 552, 465, 500, 548, 459, 442, 544, 461, 476])
ax1.plot(df['year'], OUyear, color='maroon', marker='o', label='Oklahoma')

ax1.set_title('Opponents Rushing Across 10 Years', fontsize=15, fontweight='bold')
ax1.set_ylabel('Opponents Rushing', fontsize=15, fontweight='bold')
ax1.grid(True)
ax1.tick_params(top=False, labelsize=15)
ax1.legend(fontsize=6, loc='upper right')
plt.subplots_adjust(hspace=0.2)

#----------------------------------------------------------------------------------------------------------------------------------------------#

#Second Plot

ax2.plot(df['year'], df['Opp Rush Yds'], marker='o', label='Avg Opponents Rushing Yards Across all CFB Teams', color='orange')

ou_avg_x = 2020
ou_avg_y = 1931.6
ax2.plot(ou_avg_x, ou_avg_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax2.axhline(y=ou_avg_y, linestyle='--', color='deepskyblue', linewidth=1)

xticks = list(df['year']) + [ou_avg_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax2.set_xticks(xticks)
ax2.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp=np.array([2120, 1136, 1944, 1326, 1444, 1812, 1183, 1156, 1350, 1402])
ax2.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear=np.array([1383, 2102, 2114, 2191, 2237, 1877, 1677, 2437, 1802, 1496])
ax2.plot(df['year'], OUyear, color='maroon', marker='o', label='Oklahoma')

ax2.set_title('Opponents Rushing Yards Across 10 Years', fontsize=15, fontweight='bold')
ax2.set_ylabel('Opponents Rushing Yards', fontsize=15, fontweight='bold')
ax2.grid(True)
ax2.tick_params(top=False, labelsize=15)
ax2.legend(fontsize=7)
plt.subplots_adjust(hspace=0.2)

#----------------------------------------------------------------------------------------------------------------------------------------------#

#Third graph

ax3.plot(df['year'], df['Yds/Rush'], marker='o', label='Avg Yards Per Rush Across all CFB Teams', color='orange')

ou_avg_x = 2020
ou_avg_y = 3.9
ax3.plot(ou_avg_x, ou_avg_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax3.axhline(y=ou_avg_y, linestyle='--', color='deepskyblue', linewidth=1)

xticks = list(df['year']) + [ou_avg_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax3.set_xticks(xticks)
ax3.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp=np.array([3.95, 2.43, 3.70, 2.72, 2.51, 3.72, 2.56, 2.88, 3.00, 2.65])
ax3.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear=np.array([3.02, 3.81, 4.55, 4.38, 4.08, 4.09, 3.79, 4.48, 3.91, 3.14])
ax3.plot(df['year'], OUyear, color='maroon', marker='o', label='Oklahoma')

ax3.set_title('Yards Per Rush Across 10 Years', fontsize=15, fontweight='bold')
ax3.set_ylabel('Yards Per Rush', fontsize=15, fontweight='bold')
ax3.grid(True)
ax3.tick_params(top=False, right=False, labelsize=15)
ax3.legend(fontsize=7)
plt.subplots_adjust(hspace=0.2)
#----------------------------------------------------------------------------------------------------------------------------------------------#

#Forth Plot

ax4.plot(df['year'], df['Opp Rush TDs'], marker='o', label='Avg Opponent Rushing TDs Across all CFB Teams', color='orange')

ou_avg_x = 2020
ou_avg_y = 19.1
ax4.plot(ou_avg_x, ou_avg_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax4.axhline(y=ou_avg_y, linestyle='--', color='deepskyblue', linewidth=1)

xticks = list(df['year']) + [ou_avg_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax4.set_xticks(xticks)
ax4.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp=np.array([24, 7, 20, 9, 8, 19, 3, 7, 9, 13])
ax4.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear=np.array([15, 15, 15, 24, 33, 20, 15, 29, 14, 11])
ax4.plot(df['year'], OUyear, color='maroon', marker='o', label='Oklahoma')

ax4.set_title('Opponent Rushing TDs Across 10 Years', fontsize=15, fontweight='bold')
ax4.set_ylabel('Total Yards Per Game', fontsize=15, fontweight='bold')
ax4.grid(True)
ax4.tick_params(top=False, right=False, labelsize=15)
ax4.legend(fontsize=7)
plt.subplots_adjust(hspace=0.2)

#----------------------------------------------------------------------------------------------------------------------------------------------#

#Fith Plot

ax5.plot(df['year'], df['YPG'], marker='o', label='Avg Yards Per Game Across all CFB Teams', color='orange')

ou_avg_x = 2020
ou_avg_y = 145.1
ax5.plot(ou_avg_x, ou_avg_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax5.axhline(y=ou_avg_y, linestyle='--', color='deepskyblue', linewidth=1)

xticks = list(df['year']) + [ou_avg_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax5.set_xticks(xticks)
ax5.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp=np.array([141.3, 75.7, 129.6, 94.7, 96.3, 120.8, 78.9, 77.1, 90, 87.6])
ax5.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear=np.array([106.4, 161.7, 162.6, 156.5, 159.8, 134.1, 129, 187.5, 138.6, 115.1])
ax5.plot(df['year'], OUyear, color='maroon', marker='o', label='Oklahoma')

ax5.set_title('Yards Per Game Across 10 Years', fontsize=15, fontweight='bold')
ax5.set_ylabel('Yards Per Game', fontsize=15, fontweight='bold')
ax5.grid(True)
ax5.tick_params(top=False, right=False, labelsize=15)
ax5.legend(fontsize=6)

plt.tight_layout()
plt.subplots_adjust(hspace=0.2)
plt.show()

# %% [markdown]
# # Total Offense
# #### This includes
# ##### - Total Plays Ran
# ##### - Total Yards
# ##### - Yards / Play
# ##### - Offensive Touchdowns
# ##### - Yards Per Game (YPG)

# %%
import matplotlib.pyplot as plt
import pandas as pd

df=pd.read_csv('Total Offense.csv')
fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(5, 1, figsize=(10, 32))

#----------------------------------------------------------------------------------------------------------------------------------------------#

#First graph

ax1.plot(df['year'], df['plays'], color='orange',  marker='o', label='Avg Plays Across all CFB Teams')

ou_ypp_x=2020
ou_ypp_y=938.6

ax1.plot(ou_ypp_x, ou_ypp_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax1.axhline(y=ou_ypp_y, linestyle='--', color='deepskyblue', linewidth=1)

xticks = list(df['year']) + [ou_ypp_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax1.set_xticks(xticks)
ax1.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp=np.array([1099, 1088, 1220, 944, 1076, 1080, 952, 1049, 924, 989])
ax1.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear=np.array([943, 1013, 957, 979, 928, 946, 851, 988, 974, 807])
ax1.plot(df['year'], OUyear, color='maroon', marker='o', label='Oklahoma')

ax1.set_title('Plays Ran Across 10 Years', fontsize=15, fontweight='bold')
ax1.set_ylabel('Plays', fontsize=15, fontweight='bold')
ax1.grid(True)
ax1.tick_params(top=False, right=False, labelsize=15)
ax1.legend(fontsize=6, loc='upper right')
plt.subplots_adjust(hspace=1)

#----------------------------------------------------------------------------------------------------------------------------------------------#

#Second Plot

ax2.plot(df['year'], df['yrds'], marker='o', label='Avg Yards Across all CFB Teams', color='orange')

ou_avg_x = 2020
ou_avg_y = 6687.5
ax2.plot(ou_avg_x, ou_avg_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax2.axhline(y=ou_avg_y, linestyle='--', color='deepskyblue', linewidth=1)

xticks = list(df['year']) + [ou_avg_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax2.set_xticks(xticks)
ax2.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp=np.array([7674, 6406, 7555, 6217, 7909, 8526, 6642, 7518, 5741, 6870])
ax2.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear=np.array([6041, 6893, 7212, 8114, 7984, 7527, 5863, 6162, 6591, 4488])
ax2.plot(df['year'], OUyear, color='maroon', marker='o', label='Oklahoma')

ax2.set_title('Offense Yards Across 10 Years', fontsize=15, fontweight='bold')
ax2.set_ylabel('Offense Yards', fontsize=15, fontweight='bold')
ax2.grid(True)
ax2.tick_params(top=False, right=False, labelsize=15)
ax2.legend(fontsize=7)

#----------------------------------------------------------------------------------------------------------------------------------------------#

#Third graph

ax3.plot(df['year'], df['yrds/play'], marker='o', label='Avg Yards Per Play Across all CFB Teams', color='orange')

ou_avg_x = 2020
ou_avg_y = 7.106
ax3.plot(ou_avg_x, ou_avg_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax3.axhline(y=ou_avg_y, linestyle='--', color='deepskyblue', linewidth=1)

xticks = list(df['year']) + [ou_avg_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax3.set_xticks(xticks)
ax3.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp=np.array([6.98, 5.89, 6.19, 6.59, 7.35, 7.89, 6.98, 7.17, 6.21, 6.95])
ax3.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear=np.array([6.41, 6.80, 7.54, 8.29, 8.60, 7.96, 6.89, 6.24, 6.77, 5.56])
ax3.plot(df['year'], OUyear, color='maroon', marker='o', label='Oklahoma')

ax3.set_title('Yards Per Play Across 10 Years', fontsize=15, fontweight='bold')
ax3.set_ylabel('Yards Per Play', fontsize=15, fontweight='bold')
ax3.grid(True)
ax3.tick_params(top=False, right=False, labelsize=15)
ax3.legend(fontsize=7)
#----------------------------------------------------------------------------------------------------------------------------------------------#

#Forth Plot

ax4.plot(df['year'], df['off td'], marker='o', label='Avg Offensive TDs Across all CFB Teams', color='orange')

ou_avg_x = 2020
ou_avg_y = 66.1
ax4.plot(ou_avg_x, ou_avg_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax4.axhline(y=ou_avg_y, linestyle='--', color='deepskyblue', linewidth=1)

xticks = list(df['year']) + [ou_avg_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax4.set_xticks(xticks)
ax4.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp=np.array([83, 55, 75, 64, 86, 93, 68, 75, 64, 71])
ax4.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear=np.array([57, 70, 73, 80, 85, 74, 61, 55, 66, 40])
ax4.plot(df['year'], OUyear, color='maroon', marker='o', label='Oklahoma')

ax4.set_title('Offensive TDs Across 10 Years', fontsize=15, fontweight='bold')
ax4.set_ylabel('Offensive Tds', fontsize=15, fontweight='bold')
ax4.grid(True)
ax4.tick_params(top=False, right=False,labelsize=15)
ax4.legend(fontsize=7)


#----------------------------------------------------------------------------------------------------------------------------------------------#

#Fith Plot

ax5.plot(df['year'], df['YPG'], marker='o', label='Avg Offensive Yards Per Game Across all CFB Teams', color='orange')

ou_avg_x = 2020
ou_avg_y = 504.32
ax5.plot(ou_avg_x, ou_avg_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax5.axhline(y=ou_avg_y, linestyle='--', color='deepskyblue', linewidth=1)

xticks = list(df['year']) + [ou_avg_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax5.set_xticks(xticks)
ax5.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp=np.array([511.6, 427.1, 503.7, 444.1, 527.2, 568.4, 442.8, 501.2, 382.7, 429.4])
ax5.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear=np.array([464.7, 530.2, 554.8, 579.6, 570.3, 537.6, 451, 474, 507, 374])
ax5.plot(df['year'], OUyear, color='maroon', marker='o', label='Oklahoma')

ax5.set_title('Offensive Yards Per Game Across 10 Years', fontsize=15, fontweight='bold')
ax5.set_ylabel('Offensive Yards Per Game', fontsize=15, fontweight='bold')
ax5.grid(True)
ax5.tick_params(top=False, right=False, labelsize=15)
ax5.legend(fontsize=6)

plt.tight_layout()
plt.subplots_adjust(hspace=0.3)
plt.show()

# %% [markdown]
# # Rushing Offense
# #### This includes
# ##### - Rushing Attempts
# ##### - Rushings Yards
# ##### - Yards Per Play
# ##### - Rushing Touchdowns
# ##### - Rushing Yards Per Game (YPG)

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('Rushing Offense.csv')
fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(5, 1, figsize=(10, 30))

#----------------------------------------------------------------------------------------------------------------------------------------------#

#First graph

ax1.plot(df['year'], df['rush'], color='orange', marker='o', label='Avg Rushing Att Across all CFB Teams')

ou_ypp_x = 2020
ou_ypp_y = 541.3

ax1.plot(ou_ypp_x, ou_ypp_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax1.axhline(y=ou_ypp_y, linestyle='--', color='deepskyblue', linewidth=1)

xticks = list(df['year']) + [ou_ypp_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax1.set_xticks(xticks)
ax1.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp = np.array([690, 642, 591, 612, 568, 513, 545, 557, 563, 534])
ax1.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear = np.array([557, 574, 573, 546, 527, 565, 448, 581, 521, 521])
ax1.plot(df['year'], OUyear, color='maroon', marker='o', label='Oklahoma')

ax1.set_title('Rushing Attempts Across 10 Years', fontsize=15, fontweight='bold')
ax1.set_ylabel('Rushing Attempts', fontsize=15, fontweight='bold')
ax1.grid(True)
ax1.tick_params(top=False, right=False, labelsize=15)
ax1.legend(fontsize=6, loc='upper right')
plt.subplots_adjust(hspace=1)

#----------------------------------------------------------------------------------------------------------------------------------------------#

#Second Plot

ax2.plot(df['year'], df['rush yrds'], marker='o', label='Avg Rushing Yards Across all CFB Teams', color='orange')

ou_avg_x = 2020
ou_avg_y = 2891.1
ax2.plot(ou_avg_x, ou_avg_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax2.axhline(y=ou_avg_y, linestyle='--', color='deepskyblue', linewidth=1)

xticks = list(df['year']) + [ou_avg_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax2.set_xticks(xticks)
ax2.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp = np.array([3967, 2999, 2546, 3509, 3723, 2502, 2864, 3080, 2536, 2662])
ax2.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear = np.array([3395, 2887, 3078, 3049, 3464, 3363, 2438, 2852, 2368, 2017])
ax2.plot(df['year'], OUyear, color='maroon', marker='o', label='Oklahoma')

ax2.set_title('Rushing Yards Across 10 Years', fontsize=15, fontweight='bold')
ax2.set_ylabel('Rushing Yards', fontsize=15, fontweight='bold')
ax2.grid(True)
ax2.tick_params(top=False, right=False, labelsize=15)
ax2.legend(fontsize=7)

#----------------------------------------------------------------------------------------------------------------------------------------------#

#Third graph

ax3.plot(df['year'], df['yrds/rush'], marker='o', label='Avg Yards Per Rush Across all CFB Teams', color='orange')

ou_avg_x = 2020
ou_avg_y = 5.337
ax3.plot(ou_avg_x, ou_avg_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax3.axhline(y=ou_avg_y, linestyle='--', color='deepskyblue', linewidth=1)

xticks = list(df['year']) + [ou_avg_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax3.set_xticks(xticks)
ax3.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp = np.array([5.75, 4.67, 4.31, 5.73, 6.55, 4.88, 5.26, 5.53, 4.50, 4.99])
ax3.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear = np.array([6.10, 5.03, 5.37, 5.58, 6.57, 5.95, 5.44, 4.91, 4.55, 3.87])
ax3.plot(df['year'], OUyear, color='maroon', marker='o', label='Oklahoma')

ax3.set_title('Yards Per Rush Across 10 Years', fontsize=15, fontweight='bold')
ax3.set_ylabel('Yards Per Rush', fontsize=15, fontweight='bold')
ax3.grid(True)
ax3.tick_params(top=False, right=False, labelsize=15)
ax3.legend(fontsize=7)
#----------------------------------------------------------------------------------------------------------------------------------------------#

#Forth Plot

ax4.plot(df['year'], df['rush td'], marker='o', label='Avg Rushing TDs Across all CFB Teams', color='orange')

ou_avg_x = 2020
ou_avg_y = 32.1
ax4.plot(ou_avg_x, ou_avg_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax4.axhline(y=ou_avg_y, linestyle='--', color='deepskyblue', linewidth=1)

xticks = list(df['year']) + [ou_avg_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax4.set_xticks(xticks)
ax4.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp = np.array([40, 32, 30, 33, 42, 38, 29, 28, 32, 17])
ax4.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear = np.array([41, 33, 30, 36, 49, 32, 29, 44, 40, 34])
ax4.plot(df['year'], OUyear, color='maroon', marker='o', label='Oklahoma')

ax4.set_title('Rushing TDs Across 10 Years', fontsize=15, fontweight='bold')
ax4.set_ylabel('Rushing Tds', fontsize=15, fontweight='bold')
ax4.grid(True)
ax4.tick_params(top=False, right=False, labelsize=15)
ax4.legend(fontsize=7)

#----------------------------------------------------------------------------------------------------------------------------------------------#

#Fith Plot

ax5.plot(df['year'], df['YPG'], marker='o', label='Avg Rushing Yards Per Game Across all CFB Teams', color='orange')

ou_avg_x = 2020
ou_avg_y = 216.88
ax5.plot(ou_avg_x, ou_avg_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax5.axhline(y=ou_avg_y, linestyle='--', color='deepskyblue', linewidth=1)

xticks = list(df['year']) + [ou_avg_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax5.set_xticks(xticks)
ax5.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp = np.array([511.6, 427.1, 503.7, 444.1, 527.2, 568.4, 442.8, 501.2, 382.7, 429.4])
ax5.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear = np.array([264.5, 199.9, 169.7, 250.6, 248.2, 166.8, 190.9, 205.3, 169.1, 166.4])
ax5.plot(df['year'], OUyear, color='maroon', marker='o', label='Oklahoma')

ax5.set_title('Rushing Yards Per Game Across 10 Years', fontsize=15, fontweight='bold')
ax5.set_ylabel('Rushing Yards Per Game', fontsize=15, fontweight='bold')
ax5.grid(True)
ax5.tick_params(top=False, right=False, labelsize=15)
ax5.legend(fontsize=6)

plt.tight_layout()
plt.subplots_adjust(hspace=0.2)
plt.show()

# %% [markdown]
# # Penalties
# #### This includes
# ##### - Total Penalties
# ##### - Yards Given by Penalties
# ##### - Penalties Per Game

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('Penalties.csv')
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 13))

#----------------------------------------------------------------------------------------------------------------------------------------------#

#First graph

ax1.plot(df['year'], df['penalties'], color='orange', marker='o', label='Avg Penalties Across all CFB Teams')

ou_ypp_x = 2020
ou_ypp_y = 80.3

ax1.plot(ou_ypp_x, ou_ypp_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax1.axhline(y=ou_ypp_y, linestyle='--', color='deepskyblue', linewidth=1)

champ_avg_x = 2020.5
champ_avg_y = 76.4

ax1.plot(champ_avg_x, champ_avg_y, marker='o', color='magenta', label='Champ 10yr Avg')
ax1.axhline(y=champ_avg_y, linestyle='--', color='magenta', linewidth=1)

xticks = list(df['year']) + [ou_ypp_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax1.set_xticks(xticks)
ax1.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp = np.array([84, 89, 95, 70, 73, 93, 77, 66, 45, 72])
ax1.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear = np.array([70, 80, 66, 82, 86, 101, 87, 74, 88, 69])
ax1.plot(df['year'], OUyear, color='maroon', marker='o', label='Oklahoma')

ax1.set_title('Penalties Across 10 Years', fontsize=15, fontweight='bold')
ax1.set_ylabel('Penalties', fontsize=15, fontweight='bold')
ax1.grid(True)
ax1.tick_params(top=False, right=False, labelsize=15)
ax1.legend(fontsize=6, loc='upper right')
plt.subplots_adjust(hspace=0.3)

#----------------------------------------------------------------------------------------------------------------------------------------------#

#Second Plot

ax2.plot(df['year'], df['penalty yrds'], marker='o', label='Avg Penalty Yards Across all CFB Teams', color='orange')

ou_avg_x = 2020
ou_avg_y = 756.4

ax2.plot(ou_avg_x, ou_avg_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax2.axhline(y=ou_avg_y, linestyle='--', color='deepskyblue', linewidth=1)

champ_avg_x = 2020.5
champ_avg_y = 697.2

ax2.plot(champ_avg_x, champ_avg_y, marker='o', color='magenta', label='Champ 10yr Avg')
ax2.axhline(y=champ_avg_y, linestyle='--', color='magenta', linewidth=1)

xticks = list(df['year']) + [ou_avg_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax2.set_xticks(xticks)
ax2.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp = np.array([711, 835, 870, 569, 674, 936, 638, 674, 412, 653])
ax2.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear = np.array([648, 800, 679, 808, 855, 1038, 733, 652, 760, 591])
ax2.plot(df['year'], OUyear, color='maroon', marker='o', label='Oklahoma')

ax2.set_title('Yards Given by Penalties Across 10 Years', fontsize=15, fontweight='bold')
ax2.set_ylabel('Penalty Yards', fontsize=15, fontweight='bold')
ax2.grid(True)
ax2.tick_params(top=False, right=False, labelsize=15)
ax2.legend(fontsize=7)
plt.subplots_adjust(hspace=0.3)

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('Penalties Per Game.csv')
fig, (ax1) = plt.subplots(1, 1, figsize=(10, 6))

#----------------------------------------------------------------------------------------------------------------------------------------------#

ax1.plot(df['year'], df['pen/game'], marker='o', label=' Avg Penalties Per Game Across all CFB Teams', color='orange') #change label to what you want the title for the legend to be of the national avg spreadhseet you made.

ou_avg_x = 2020 #dont change this
ou_avg_y = 6.034 # add up specific data for ou for each year divided by 10

ax1.plot(ou_avg_x, ou_avg_y, marker='o', color='deepskyblue', label='OU 10yr Avg')
ax1.axhline(y=ou_avg_y, linestyle='--', color='deepskyblue', linewidth=1)

champ_avg_x = 2020.5 #dont change this
champ_avg_y = 5.086 # add up specific data for ou for each year divded byy 10

ax1.plot(champ_avg_x, champ_avg_y, marker='o', color='magenta', label='Champ 10yr Avg')
ax1.axhline(y=champ_avg_y, linestyle='--', color='magenta', linewidth=1)

xticks = list(df['year']) + [ou_avg_x]
xtick_labels = list(df['year'].astype(str)) + ['OU Avg']
ax1.set_xticks(xticks)
ax1.set_xticklabels(xtick_labels, rotation=60, ha='right', fontsize=9)

natchamp = np.array([5.60, 5.93, 6.33, 5.00, 4.87, 6.10, 5.13, 4.40, 3.00, 4.50]) #the specific stat for that year, these stats are in order of 2014, 2015, 2016.... so 5.60 is the stat for the championship team in 2014
ax1.plot(df['year'], natchamp, color='green', marker='o', label='NCAA Title Winner')

OUyear = np.array([5.38, 6.15, 5.08, 5.86, 6.14, 7.27, 6.69, 5.69, 6.77, 5.31]) #same thing as above but for ou. to get the value for the "ou_avg_y" variable you add all ten of these up and divide by 10
ax1.plot(df['year'], OUyear, color='maroon', marker='o', label='Oklahoma')

ax1.set_title('Penalties Per Game Across 10 Years', fontsize=15, fontweight='bold') #Title for graph
ax1.set_ylabel('Penalties Per Game', fontsize=15, fontweight='bold') # y - axis label
ax1.grid(True)
ax1.tick_params(top=False, right=False, labelsize=15)
ax1.legend(fontsize=7)
plt.subplots_adjust(hspace=0.3) #changes the space between graphs

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
passo = pd.read_csv('passingoffense(Sheet1).csv') #read in data

# %%
pychamp = [3707,3407,5009,2708,4185,6024,3778,4438,3205,4208]
fig, (ax1) = plt.subplots(1, 1, figsize=(10, 6))
#----------------------------------------------------------------------------------------------------------------------------------------------#

ax1.plot(passo['year'], passo['pass yds'], marker='o', label='Average Passing Yds Across all CFB Teams', color='black') #change label to what you want the title for the legend to be of the national avg spreadhseet you made.

champx = passo['year'] 
champy = pychamp

ax1.plot(champx, champy, marker='o', color='gold', label='Champ Pass Yards')

oupassing = np.array([2646, 4006, 4134, 5065, 4520, 4164, 3425, 3310, 4223, 2286]) 
ax1.plot(passo['year'], oupassing, color='maroon', marker='o', label='Oklahoma')

ax1.set_title('Total Passing Yds Across 10 Years', fontsize=15, fontweight='bold') #Title for graph
ax1.set_ylabel('Passing Yards', fontsize=15, fontweight='bold') # y - axis label
ax1.grid(True)
ax1.tick_params(top=False, right=False, labelsize=15)
ax1.legend(fontsize=7)
plt.subplots_adjust(hspace=0.3) #changes the space between graphs

# %%
fig, (ax1) = plt.subplots(1, 1, figsize=(10, 6))
#----------------------------------------------------------------------------------------------------------------------------------------------#

ax1.plot(passo['year'], passo['pass att'], marker='o', label='Average Passing Attempts Across all CFB Teams', color='black') #change label to what you want the title for the legend to be of the national avg spreadhseet you made.

champx = passo['year'] 
champy = [409,446,629,332,508,567,407,492,361,455] #Not finsihed need to do

ax1.plot(champx, champy, marker='o', color='gold', label='Champ Pass Attempts')

oupassing = np.array([386,439,384,433,401,381,403,407,453,373]) 
ax1.plot(passo['year'], oupassing, color='maroon', marker='o', label='Oklahoma')

ax1.set_title('Total Passing Attempts Across 10 Years', fontsize=15, fontweight='bold') #Title for graph
ax1.set_ylabel('Passing Att', fontsize=15, fontweight='bold') # y - axis label
ax1.grid(True)
ax1.tick_params(top=False, right=False, labelsize=15)
ax1.legend(fontsize=7)
plt.subplots_adjust(hspace=0.3) #changes the space between graphs

# %%
fig, (ax1) = plt.subplots(1, 1, figsize=(10, 6))
#----------------------------------------------------------------------------------------------------------------------------------------------#

ax1.plot(passo['year'], passo['ypg'], marker='o', label='Average Passing Yards Per Game Across all CFB Teams', color='black') #change label to what you want the title for the legend to be of the national avg spreadhseet you made.

champx = passo['year'] 
champy = [247.1,] #Not finsihed need to do

ax1.plot(champx, champy, marker='o', color='gold', label='Champ Pass Yards Per Game')

oupassing = np.array([203.5,]) 
ax1.plot(passo['year'], oupassing, color='maroon', marker='o', label='Oklahoma')

ax1.set_title('Total Passing Yards Per Game Across 10 Years', fontsize=15, fontweight='bold') #Title for graph
ax1.set_ylabel('Passing Yards Per Game', fontsize=15, fontweight='bold') # y - axis label
ax1.grid(True)
ax1.tick_params(top=False, right=False, labelsize=15)
ax1.legend(fontsize=7)
plt.subplots_adjust(hspace=0.3) #changes the space between graphs

# %%
sacks = pd.read_csv('sacksallowed(Sheet1).csv')

# %%
fig, (ax1) = plt.subplots(1, 1, figsize=(10, 6))
#----------------------------------------------------------------------------------------------------------------------------------------------#

ax1.plot(sacks['year'], sacks['opp sack yds'], marker='o', label='Average Opp Sack Yards Across all CFB Teams', color='black') #change label to what you want the title for the legend to be of the national avg spreadhseet you made.

champx = sacks['year'] 
champy = [203,189,114,154,115,221,121,67,155,96] #Not finsihed need to do

ax1.plot(champx, champy, marker='o', color='gold', label='Champ Opp Sack Yards')

ousacks = np.array([58,216,134,181,116,147,183,160,122,299]) 
ax1.plot(sacks['year'], ousacks, color='maroon', marker='o', label='Oklahoma')

ax1.set_title('Total Opp Sack Yards Across 10 Years', fontsize=15, fontweight='bold') #Title for graph
ax1.set_ylabel('Opp Sack Yards', fontsize=15, fontweight='bold') # y - axis label
ax1.grid(True)
ax1.tick_params(top=False, right=False, labelsize=15)
ax1.legend(fontsize=7)
plt.subplots_adjust(hspace=0.3) #changes the space between graphs

# %% [markdown]
# ### Statistics where the champ is above the mean for the league for every year

# %% [markdown]
# Defense: Yards per play across 10 years, total plays across 10 years, total yards per game across 10 years, opponent TDs across 10 years, sacks across 10 years, total sacked yards for loss across 10 years, yardage gained on turnovers across 10 years, opponent rushing yards, yards per rush, yards per game.

# %% [markdown]
# Offense: Total plays ran, offense yards across 10 years, yards per play across 10 years, offensive TDs across 10 years, rushing attempts across 10 years, rushing yards across 10 years, rushing yards per game across 10 years.
