# %%
import numpy as np
import matplotlib as plt
import pandas as pd

# %%
#Setting up plot

fontsize = 20
figsize = (10,7)

# Configure parameters
plt.rcParams.update({'font.size': fontsize, 'figure.figsize': figsize})

# Set default tick and axes properties
plt.rcParams['xtick.labelsize'] = fontsize
plt.rcParams['ytick.labelsize'] = fontsize
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.rcParams['xtick.major.size'] = 8
plt.rcParams['ytick.major.size'] = 8
plt.rcParams['xtick.major.width'] = 4
plt.rcParams['ytick.major.width'] = 4
plt.rcParams['xtick.minor.size'] = 6
plt.rcParams['ytick.minor.size'] = 6
plt.rcParams['xtick.minor.width'] = 2
plt.rcParams['ytick.minor.width'] = 2
plt.rcParams['xtick.top'] = True
plt.rcParams['ytick.right'] = True
plt.rcParams['axes.linewidth'] = 3

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('Cmp v Att Offense.csv')

# Define your special year as a variable
z = 2019  #i set it to 2019 because the graph is super stretched if i set it to 2000, unsure how to fix
champ_cmp = 24.1
champ_att = 37.5

plt.figure(figsize=(8, 5))

plt.plot(df['Year'], df['Cmp'], marker='o', label='Completions') #plotting offensive main data
plt.plot(df['Year'], df['Att_pass'], marker='o', label='Attempts')

plt.plot( # plotting for z
    [z, z],
    [champ_cmp, champ_att],
    marker='o',
    linestyle='None',
    color='maroon',
    label='Championship Team (z)'
)

plt.text(z, champ_cmp + 0.5, 'z', ha='center', color='maroon',fontsize=15) #both of these are for the maroon points
plt.text(z, champ_att + 0.5, 'z', ha='center', color='maroon',fontsize=15)

plt.title('Passing Trends 2020-2024 (Offense)')
plt.xlabel('Year')
plt.ylabel('Per Game Average')
plt.ylim(0, 40)
plt.legend(fontsize=10)
plt.grid(True)
plt.tight_layout()
plt.tick_params(top=False)
plt.show()

# %%
z_cmp = 24.1
z_att = 37.5
cmp_2020=22.6
cmp_2021=21.5
cmp_2022=19.3
cmp_2023=23.8
cmp_2024=18.1
ou_cmp_avg=(cmp_2020+cmp_2021+cmp_2022+cmp_2023+cmp_2024)/5
print('The avergae of OUs passing completions is', round(ou_cmp_avg, 1), 'compared to to the championship teams of', z_cmp, 'which is about 3% lower than the championship team.')
# Out:
# The avergae of OUs passing completions is 21.1 compared to to the championship teams of 24.1 which is about 3% lower than the championship team.
